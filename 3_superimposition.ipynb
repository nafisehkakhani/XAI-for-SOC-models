# %% [markdown]
# ### Overlaying the random points on features that have been prepared in raster format.

# %%
from utils.utils import *

# %%
directory = 'D:\KillMe\TOC_features4'
crs = 'EPSG:4326'  # Example CRS, you should specify the appropriate CRS for your data

# %% [markdown]
# ### Read the rester files and put them into an array

# %%
# Selected samples
points_csv_path = 'C:\\....\\random_samples_large.csv'
output_csv_path = 'C:\\...\\Superimposition_all_.csv'

data_arrays = read_tiff_files_with_same_crs(directory, crs)
# Out:
# Reading TIFF files: 100%|██████████| 48/48 [00:00<00:00, 519.51files/s]

# %% [markdown]
# ### Superimposition of points on rasters

# %%
overlay_points_on_data(data_arrays, points_csv_path, output_csv_path)
# Out:
# Overlaying points:   0%|          | 0/48 [00:00<?, ?array/s]
# aet
# Overlaying points:   2%|▏         | 1/48 [02:36<2:02:43, 156.66s/array]
# Analytical Hillshading
# Overlaying points:   4%|▍         | 2/48 [05:10<1:58:40, 154.79s/array]
# Aspect
# Overlaying points:   6%|▋         | 3/48 [07:43<1:55:40, 154.23s/array]
# BulkDensb0_Germany
# Overlaying points:   8%|▊         | 4/48 [10:14<1:51:57, 152.68s/array]
# Channel Network Base Level
# Overlaying points:  10%|█         | 5/48 [12:46<1:49:16, 152.48s/array]
# Channel Network Distance
# Overlaying points:  12%|█▎        | 6/48 [15:18<1:46:47, 152.57s/array]
# Clayb0_Germany
# Overlaying points:  15%|█▍        | 7/48 [17:52<1:44:33, 153.00s/array]
# Closed Depressions
# Overlaying points:  17%|█▋        | 8/48 [20:25<1:41:55, 152.89s/array]
# Convergence Index
# Overlaying points:  19%|█▉        | 9/48 [23:01<1:39:56, 153.77s/array]
# def
# Overlaying points:  21%|██        | 10/48 [25:34<1:37:22, 153.76s/array]
# HLS_bi
# ...

# %% [markdown]
# ### Explore the extracted data

# %%
# # Example usage:
# plot_dataframe_histogram(output_csv_path)

# %%
import pandas as pd


# # List of columns to exclude for GT
# exclude_columns = ['OID_', 'Point_ID', 'Coarse', 'Clay', 'Sand', 'Silt', 'pH_CaCl2', 'pH_H20',
#                    'EC', 'CaCO3', 'P', 'N', 'K', 'LC', 'LU', 'NUTS_0', 'NUTS_1', 'NUTS_2',
#                    'NUTS_3', 'LC0_Desc', 'LC1_Desc', 'LU1_Desc']

# List of columns to exclude for selected samples
exclude_columns = ['OID_', 'Point_ID']

# Read CSV file into a Pandas DataFrame
df = pd.read_csv(output_csv_path)

# Drop columns to exclude
df = df.drop(columns=exclude_columns)

value_to_replace = -99999

# Replace specific values with NaN
df = df.replace(value_to_replace, np.nan)

# %%
from sklearn.impute import KNNImputer

# Assuming df is your DataFrame with NaN values

# Instantiate the KNNImputer with desired parameters
imputer = KNNImputer(n_neighbors=5, weights='distance')  # You can adjust parameters as needed

# Fit the imputer model on your data and transform it to fill NaN values
filled_df = pd.DataFrame(imputer.fit_transform(df), columns=df.columns)

# Assuming df is your DataFrame
filled_df_numeric = filled_df.apply(pd.to_numeric, errors='coerce')

# %%
# Save overlaid points data to CSV file

# # Saving GT
# filled_df.to_csv('input_features.csv', index=False)

# Saving selected samples
filled_df.to_csv('input_features_all.csv', index=False)

# %% [markdown]
# ### Raster Exploration

# %%
plot_dataframe_histogram(output_csv_path)
